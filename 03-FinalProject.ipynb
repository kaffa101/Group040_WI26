# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
# Course drop behavior is critical in understanding students‘ academic experiences, as dropping a course may potentially reflect the difficulties related to course workload, course structure, grading expectations, or even the instructor's teaching ability. In this project, we examined whether course drop rates of Cognitive Science (COGS) courses in UCSD were associated with three factors: average study hours per week, professor recommendation ratings, and average grades of the courses. These variables may capture how demanding, rewarding, or manageable a course feels to students, and therefore help explain differences in drop behavior across courses.
#
# To investigate this, we combined COGS course enrollment data from Fall 2022 through Spring 2023 with CAPE course evaluation data, cleaned and merged the datasets, and constructed a dataframe for exploratory analysis. Then we used descriptive statistics, scatterplots, correlation analysis, and grouped comparisons to examine the relationships between drop rate and the key variables. Our results show that these variables are sightly, but not strongly, associated with drop rate overall. Study hours showed a weak positive relationship with dropping, professor recommendation showed a weak negative relationship with drop rate, and average grade appeared to have minor explanatory power. Overall, our findings suggest that, while course evaluations may capture some patterns related to dropping behavior, they still do not strongly explain variation in course drop rates due to reason including ceiling effects, and the results should be interpreted cautiously given the limitations of the available data.

# %% [markdown]
# ## Authors
# - Brian Chung:
# - Ji Yoo Dojun:
# - George Payba: Added explainations
# - Dexter Xu: Merged dataframes, updated ethics section
# - Vincent Yang: Background research, Data curation, Methodology, Writing – original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a relationship between the COGS course drop rate at UCSD and students' evaluations of these courses - specifically course workload (study hours per week), instructor ratings, and average course grades - using CAPE evaluation data from 2022-23 school year (FA22 - SP23), on COGS1, 14A, 17, 101B, and 107A?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# It's so common for college students to choose to drop their courses within the beginning few weeks of a new quarter, that we often overlook the significance behind this behavior: what factors could actually be correlated with this complex decision - giving up a course that is planned or even anticipated for months since registration? Specifically, aside from non-academic reasons, what aspects of a course itself may be associated with a high withdrawal rate?
#
# One previous research has been conducted on the affective reasoning of why students might choose to withdraw courses.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Among the multiple reasons for dropping from a course, "at risk of failing the course" is ranked at the top with a 39.9% probability of withdrawing. In other words, students may tend to drop courses if they feel they may get bad grades, mainly due to the difficulty, as the courses continue.
#
# Another research has pointed out that "assignment too heavy" could be a reason of dropping courses as well.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) This term, first of all, may be regarded as an implication of the difficulty of the course. However, this research was conducted through community colleges, and academic workload is related to job conflict (time conflict) specifically in this case. Therefore, heavy assignments also represent time consuming tasks.
#
# We also discovered a prior study that takes the teaching quality into account.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) By examining SRT (students rating of teaching) data, the researchers show that students can have their own evaluations of the instructors only after taking a few classes, which is then a critical factor of if the students will drop the course. Noteworthy, this factor is isolated from the probability of receiving bad grades or being assigned heavy tasks, because teaching methods or attitudes of professors do not necessarily relate to their assignments or rating scales.
#
# Drawing on the findings of the researches above, we include three major instructional factors - average course grades, course workload (work time), and instructor ratings - in our research of their correlations to the students' dropping rate of COGS courses at UCSD, examining if they show the same correlations in our case as well.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Wheland, E., Butler, J., Qammar, H., & Katz-Harris, S. (n.d.). *What Are They Thinking? Students’ Affective Reasoning and Attitudes about Course Withdrawal* (pp. 17–25). https://www.montana.edu/rmaher/barrier_courses/32-2-Wheland-Butler-Qammar-Katz%20Harris-pp17-25.pdf
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Friedlander, J. (1981). *Why Students Drop Courses*. Junior College Resource Review (ERIC Document ED196505). https://files.eric.ed.gov/fulltext/ED196505.pdf
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Babad, E., Icekson, T., & Yelinek, Y. (2008). *Antecedents and correlates of course cancellation in a university “drop and add” period*. Research in Higher Education, 49(4), 293–316. https://doi.org/10.1007/s11162-007-9082-3

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that there is likely a strong correlation between COGS course drop rate at UCSD and students' evaluations. We predict that courses with a higher workload, lower professor rating and lower grades are likely to have a higher drop rate. All these factors represent a class with a higher difficulty, which we believe will lead to a greater number of students dropping said class.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
# The "ideal" dataset that we would be looking for should contain information like instructor ratings, average course grades, number of students enrolled, and a measurement of their workload. Variables like average grade and instructor ratings will be continuous, along with discrete variables such as the amount of students enrolled, and what course they are enrolled in. We will be looking at data from the 2022 Fall quarter to 2023 Spring quarter via CAPE evaluations which are publically available. The data would be stored in a table grouped by the course id / course name, and for each of these we would have data containing the average grades received, instructor recommending rates, course workloads, and drop rates. Some datasets that already exist include CAPE Evals. These are stored as URLs, and are publically available to everyone. Another public student made dataset exists in Github, containing data recorded from webreg, which include the times at which students dropped or enrolled in the class.
#
#
#
# - Dataset #1
#   - Name: capes_data.csv (raw), capes_clean.csv (processed)
#   - Link: https://www.kaggle.com/datasets/sanbornpnguyen/ucsdcapes
#   - Number of observations: 63363 (raw), 81 (processed)
#   - Number of variables: 11 (raw), 5 (processed)
#   - Variables most relevant to the project: we will be focusing on the variables "Percentage Recommended Professor", "Study Hours per Week", and "Average Grade Received". The "Percentage Recommended Professor" is a percentage that stands for what proportion of the CAPEs would recommend the professor (not the course itself), which is the instructor rating. The "Studys Hours per Week" gives float data to two decimal places on the average study hours per week among the CAPEs, in other words, the workload. The "Average Grade Received" variable is for the actual average grade that the CAPEs received on this course, both in the form of letter grade and a more detailed two decimal place GPA out of 4.
#   - Shortcomings: It must be admitted that not everyone enrolled in the course responded on the CAPE, which may cause the dataset less representative to the actual entire course situation.
#
# &nbsp;
# - Dataset #2
#   - Name: enroll_clean.csv (processed) (original data consist of multiple datasets)
#   - Link: https://github.com/UCSD-Historical-Enrollment-Data/UCSDHistEnrollData
#   - Number of observations: 400536 (processed)
#   - Number of variables: 5 (raw), 7 (processed)
#   - Variables most relevant to the project: we will mostly be focusing on the variable "enrolled" and "waitlisted". "Enrolled" displays integer numbers of the currently enrolled number of people to the course over time. "Waitlisted" displays the integer numbers of the currently waitlisted number of people to the course over time. We will monitor their changes from the beginning of the quarter to the end of week 4 - when the "drop" action ends. Everytime the "enrolled" number decreases by 1 from the beginning of instruction to the end of week 4, we count it as 1 person dropping.
#   - Shortcomings: Since the dataset only provides the changes of enrollment and waitlist number over the time, but not directly showing when the "drop" action happens, we can only infer drop data from the changes of enrollment, which may not be too precise.

# %%
import pandas as pd
import os 
def drop_rate(course):
    diff = course['enrolled'].diff().fillna(0)
    total_enroll = int(diff[diff > 0].sum())
    total_drop = int((-diff[diff < 0]).sum())
    if total_enroll == 0:
        drop_rate = 0
    else:
        drop_rate = round((total_drop / total_enroll) * 100, 2)
    return total_enroll, total_drop, drop_rate

def quarter_to_df(file):
    results = []
    for filename in os.listdir(file):
        if filename.endswith(".csv"):
            file_path = os.path.join(file, filename)
            df = pd.read_csv(file_path)
            enroll, drop, rate = drop_rate(df)
            course_name = filename.replace(".csv", "")
            results.append({"course": course_name, "total_enrolled": enroll, \
                "total_dropped": drop, "drop_rate_percent": rate})
    results_df = pd.DataFrame(results)
    results_df = results_df.set_index("course")
    return results_df

# %%
FA22 = quarter_to_df("data/00-raw/COGS_22FA/")
SP23 = quarter_to_df("data/00-raw/COGS_23SP/")
WI23 = quarter_to_df("data/00-raw/COGS_23WI/")

# %%
FA22
# Out:
#            total_enrolled  total_dropped  drop_rate_percent
# course
# COGS 116              129             38              29.46
# COGS 101B             207             23              11.11
# COGS 87                77             46              59.74
# COGS 101C             201             50              24.88
# COGS 101A             425             84              19.76
# COGS 8                 25             14              56.00
# COGS 9                427            118              27.63
# COGS 100              386             87              22.54
# COGS 128               59             20              33.90
# COGS 110              110             42              38.18
# COGS 107A             490             69              14.08
# COGS 175               51             28              54.90
# COGS 160               16              5              31.25
# COGS 18               418             75              17.94
# ...

# %%
WI23
# Out:
#            total_enrolled  total_dropped  drop_rate_percent
# course
# COGS 101B             376             83              22.07
# COGS 87                32             17              53.12
# COGS 101C             158             20              12.66
# COGS 115               79             21              26.58
# COGS 101A             407             29               7.13
# COGS 9                299             52              17.39
# COGS 100              409             83              20.29
# COGS 111              235             60              25.53
# COGS 107A             344            104              30.23
# COGS 160               24              5              20.83
# COGS 107B             343             50              14.58
# COGS 189              255             80              31.37
# COGS 18               388             45              11.60
# COGS 163               94             25              26.60
# ...

# %%
SP23
# Out:
#            total_enrolled  total_dropped  drop_rate_percent
# course
# COGS 101B             313             24               7.67
# COGS 87                37             24              64.86
# COGS 101A             158             30              18.99
# COGS 8                 49             15              30.61
# COGS 9                392             98              25.00
# COGS 100              386             45              11.66
# COGS 138               56             17              30.36
# COGS 112              227             39              17.18
# COGS 107A             383             45              11.75
# COGS 160               15              0               0.00
# COGS 18               387             44              11.37
# COGS 107C             238             26              10.92
# COGS 198                5              1              20.00
# COGS 164              170             32              18.82
# ...

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### CAPEs Dataset
# #### Data Cleaning
# We only need the CAPE data of COGS courses from FA22 to SP23, and we only need the "Percentage Recommended Professor", "Study Hours per Week", and "Average Grade Received" columns as our variables.

# %%
capes_data = pd.read_csv('data/00-raw/capes_data.csv')
print(capes_data.shape)
capes_clean = capes_data.drop(['Instructor', 'Total Enrolled in Course', \
    'Total CAPEs Given','Average Grade Expected', 'Evalulation URL', 'Percentage Recommended Class'], axis=1)
capes_cogs = capes_clean[capes_clean['Course'].str.contains('COGS ')]
quar_interval = ['FA22', 'WI23', 'SP23']
capes_clean = capes_cogs[capes_cogs['Quarter'].isin(quar_interval)]
capes_clean = capes_clean.dropna()
# drop rows containing null
capes_clean.to_csv("data/02-processed/capes_clean.csv", index=False)
capes_clean
# (this was test) hi = capes_quar[capes_quar['Quarter'].str.contains('FA23')]
# hi
# Now, the capes_clean.csv only contains data for COGS courses, from FA22 to SP23.
# Out:
# (63363, 11)
#                                               Course Quarter  \
# 229       COGS 1 - Introduction to Cognitive Sci (A)    SP23
# 230     COGS 100 - Cyborgs Now and in the Future (A)    SP23
# 231         COGS 101A - Sensation and Perception (A)    SP23
# 232    COGS 101B - Learning Memory and Attention (A)    SP23
# 233      COGS 107A - Neuroanatomy and Physiology (A)    SP23
# ...                                              ...     ...
# 2935            COGS 18 - Introduction to Python (A)    FA22
# 2936  COGS 187A - Usability & Info. Architecture (A)    FA22
# 2937           COGS 2 - Cognitive NeuroEconomics (A)    FA22
# 2939          COGS 3 - Introduction to Computing (A)    FA22
# 2942       COGS 9 - Introduction to Data Science (A)    FA22
#
#      Percentage Recommended Professor  Study Hours per Week  \
# 229                             99.4%                  3.37
# 230                             87.0%                  2.52
# ...

# %% [markdown]
# ### Enrollment Dataset
# #### Datasets Merging
# We have the FA22 - SP23 COGS courses enrollment data in our raw data folder. However, they are messy, individual csv files, and lack proper identifications indicating their quarter. Here, we need to merge all these datasets into one big csv file, also adding two new columns "class" and "quarter" to identify the data in the new file. The merged file will be saved in the interim folder.

# %%
import glob

quarter_folders = {
    'FA22': 'data/00-raw/COGS_22FA',
    'WI23': 'data/00-raw/COGS_23WI',
    'SP23': 'data/00-raw/COGS_23SP',
}
df_list = []
for quarter, folder in quarter_folders.items():
    pattern = os.path.join(folder, '*.csv')
    for path in glob.glob(pattern):
        df = pd.read_csv(path)
        filename = os.path.basename(path)          
        class_name = os.path.splitext(filename)[0]   
        df['class'] = class_name
        df['quarter'] = quarter
        df_list.append(df)

merged_df = pd.concat(df_list, ignore_index=True)
merged_df.to_csv('data/01-interim/merged_cogs.csv', index = False)
merged_df.head()
# Out:
#                   time  enrolled  available  waitlisted  total     class  \
# 0  2022-05-18T04:31:26         0        156           0    156  COGS 116
# 1  2022-05-18T04:42:00         0        156           0    156  COGS 116
# 2  2022-05-18T04:52:10         0        156           0    156  COGS 116
# 3  2022-05-18T05:02:21         0        156           0    156  COGS 116
# 4  2022-05-18T05:12:31         0        156           0    156  COGS 116
#
#   quarter
# 0    FA22
# 1    FA22
# 2    FA22
# 3    FA22
# 4    FA22

# %% [markdown]
# #### Data Cleaning
# Now, we have the merged csv file, but it is surprisingly huge. Although there's no missing value due to the nature of the enrollment data, because the file records every 10 mins since the first day to course enrollment, we actually don't need most of the data and should only keep the parts from the beginning of a new quarter's instruction to the end of week 4 of that quarter (the course withdrawl happening before a quarter starts should not be counted as an action related to the course itself). Therefore, we need to delete the undesired data from the file and only keep data from these three time ranges: 2022.09.22 - 2022.10.21, 2023.01.09 - 2023.02.03, and 2023.04.03 - 2023.04.28. We will save the new csv file in the processed data folder.

# %%
merged_df['time'] = pd.to_datetime(merged_df['time'])
time_ranges = [
    ('2022-09-22', '2022-10-21'),
    ('2023-01-09', '2023-02-03'),
    ('2023-04-03', '2023-04-28'),
]
ranges = []
for i, (start, end) in enumerate(time_ranges, start = 1):
    df_ranges = merged_df[(merged_df['time'] >= start) & (merged_df['time'] <= end)].copy()
    ranges.append(df_ranges)
clean_enroll = pd.concat(ranges, ignore_index = True)
clean_enroll.to_csv('data/02-processed/enroll_clean.csv')
clean_enroll.shape
# Out:
# (400536, 7)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# In this section, we analyze whether COGS course drop rate is associated with three course-evaluation factors from CAPE data: workload (`Study Hours per Week`), instructor rating (`Percentage Recommended Professor`), and performance (`Average Grade Received`).
#
# To keep this section reproducible and fast to run, we directly load the processed files from `data/02-processed`:
# - `capes_clean.csv` (evaluation features)
# - `enroll_clean.csv` (time-series enrollment snapshots)
#
# We first build a course-quarter drop-rate table from enrollment changes, merge it with CAPE variables, and then examine distributions and pairwise relationships using visual EDA.
#
# **Drop-rate definition used in EDA:**
# \[
# \text{drop\_rate} = \frac{\text{total\_drop}}{\text{starting\_enrolled} + \text{total\_add}} \times 100
# \]
# This avoids impossible values above 100% caused by using only within-window adds in the denominator.

# %% [markdown]
# #### Section 1: Build Analysis Table + Univariate Distributions
#
# This section constructs the final EDA table at the `class x quarter` level and checks distributions/outliers for the variables used in our research question.

# %% [markdown]
# ##### Initialization

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sp

sns.set_theme(style='whitegrid', context='notebook', palette='deep', font='serif')

# load the processed datasets
capes = pd.read_csv('data/02-processed/capes_clean.csv')
enroll = pd.read_csv('data/02-processed/enroll_clean.csv')

# %% [markdown]
# ##### Helper functions

# %%
def parse_percentage(value):
    if pd.isna(value):
        return np.nan
    return float(str(value).replace('%', '').strip())

def parse_gpa(value):
    if pd.isna(value):
        return np.nan
    match = re.search(r'\((\d+(?:\.\d+)?)\)', str(value))
    return float(match.group(1)) if match else np.nan

def extract_class_name(course_text):
    if pd.isna(course_text):
        return np.nan
    match = re.search(r'(COGS\s+\d+[A-Z]?)', str(course_text))
    return match.group(1) if match else np.nan

def compute_drop_metrics(group):
    # Enrollment snapshots can have many add/drop events. Using
    # total_drop / total_add can exceed 100% when a class starts with
    # non-zero enrollment before our observation window.
    #
    # We approximate drop rate as:
    #   total_drop / (starting_enrolled + total_add)
    # which is bounded in [0, 100] for this dataset and better reflects
    # the proportion of enrollment opportunities that ended in drops.
    diff = group['enrolled'].diff().fillna(0)
    total_add = int(diff[diff > 0].sum())
    total_drop = int((-diff[diff < 0]).sum())
    starting_enrolled = int(group['enrolled'].iloc[0]) if len(group) else 0
    total_exposure = starting_enrolled + total_add

    if total_exposure == 0:
        drop_rate = 0.0
    else:
        drop_rate = round((total_drop / total_exposure) * 100, 2)

    return pd.Series({
        'starting_enrolled': starting_enrolled,
        'total_add': total_add,
        'total_drop': total_drop,
        'total_exposure': total_exposure,
        'drop_rate': drop_rate,
        'n_snapshots': len(group)
    })

# %% [markdown]
# ##### Process data for plotting

# %%
enroll['time'] = pd.to_datetime(enroll['time'])
enroll = enroll.sort_values(['class', 'quarter', 'time']).copy()

drop_df = (
    enroll.groupby(['class', 'quarter'])
    .apply(compute_drop_metrics, include_groups=False)
    .reset_index()
)

capes = capes.copy()
capes['class'] = capes['Course'].apply(extract_class_name)
capes['quarter'] = capes['Quarter'].astype(str).str.strip().str.upper()
capes['prof_recommend_pct'] = capes['Percentage Recommended Professor'].apply(parse_percentage)
capes['grade_gpa'] = capes['Average Grade Received'].apply(parse_gpa)
capes['study_hours'] = pd.to_numeric(capes['Study Hours per Week'], errors='coerce')

eda_df = capes.merge(drop_df, on=['class', 'quarter'], how='inner')
analysis_cols = ['drop_rate', 'study_hours', 'prof_recommend_pct', 'grade_gpa']
eda_df = eda_df.dropna(subset=analysis_cols).copy()

print('Rows in final EDA table:', len(eda_df))
print('Unique course-quarter combinations:', eda_df[['class', 'quarter']].drop_duplicates().shape[0])
print('Max drop rate:', eda_df['drop_rate'].max())
display(eda_df[['class', 'quarter'] + analysis_cols].head(10))
display(eda_df[analysis_cols].describe().T)
display(eda_df.head())
# Out:
# Rows in final EDA table: 81
# Unique course-quarter combinations: 81
# Max drop rate: 55.21
#        class quarter  drop_rate  study_hours  prof_recommend_pct  grade_gpa
# 0     COGS 1    SP23       3.73         3.37                99.4       3.53
# 1   COGS 100    SP23       3.94         2.52                87.0       3.96
# 2  COGS 101A    SP23      10.42         4.03                88.7       3.13
# 3  COGS 101B    SP23       3.02         4.01                98.9       3.56
# 4  COGS 107A    SP23       3.63         5.73                93.4       3.29
# 5  COGS 107C    SP23       3.60         3.96                95.9       3.74
# 6   COGS 108    SP23       6.25         5.11                96.4       3.78
# 7   COGS 109    SP23      20.11         6.36                87.8       3.35
# 8   COGS 112    SP23      11.27         3.05               100.0       3.81
# 9  COGS 118A    SP23      12.22         7.32                73.3       3.19
# ...

# %% [markdown]
# ##### Univariate

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
plot_map = [
    ('drop_rate', 'Drop Rate (%)'),
    ('study_hours', 'Study Hours / Week'),
    ('prof_recommend_pct', 'Professor Recommendation (%)'),
    ('grade_gpa', 'Average Grade GPA')
]
hist_colors = sns.color_palette('Set2', 4)

for ax, (col, title), color in zip(axes.flatten(), plot_map, hist_colors):
    sns.histplot(data=eda_df, x=col, bins=15, kde=True, ax=ax, color=color, edgecolor='white', alpha=0.9)
    ax.set_title(title)
    ax.set_xlabel(title)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# Zoom the quarter boxplot so outliers do not squash the boxes
plt.figure(figsize=(8, 4))
quarter_order = sorted(eda_df['quarter'].dropna().unique())
q1, q3 = eda_df['drop_rate'].quantile([0.25, 0.75])
iqr = q3 - q1
upper_fence = q3 + 1.5 * iqr
visible_df = eda_df[eda_df['drop_rate'] <= upper_fence].copy()
outlier_count = int((eda_df['drop_rate'] > upper_fence).sum())

sns.boxplot(
    data=visible_df,
    x='quarter',
    y='drop_rate',
    hue='quarter',
    order=quarter_order,
    palette='Set1',
    legend=False,
    showfliers=False
)
sns.stripplot(
    data=visible_df,
    x='quarter',
    y='drop_rate',
    order=quarter_order,
    color='black',
    alpha=0.35,
    size=3
)

plt.title(f'Drop Rate Distribution by Quarter (outliers hidden: {outlier_count})')
plt.xlabel('Quarter')
plt.ylabel('Drop Rate (%)')
plt.tight_layout()
plt.show()

# Full-range version (includes all points/outliers)
plt.figure(figsize=(8, 4))
sns.boxplot(
    data=eda_df,
    x='quarter',
    y='drop_rate',
    hue='quarter',
    order=quarter_order,
    palette='Set1',
    legend=False,
    showfliers=True
)
sns.stripplot(
    data=eda_df,
    x='quarter',
    y='drop_rate',
    order=quarter_order,
    color='black',
    alpha=0.25,
    size=3
)
plt.title('Drop Rate Distribution by Quarter (full range)')
plt.xlabel('Quarter')
plt.ylabel('Drop Rate (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# Graph 1: Drop Rate Histogram
#
# This is the distribution of course drop rates. The distribution is right-skewed which means that few class have high drop rates. Usually the drop rate is most couses is between ~3 and ~15%, but in the most extreme of cases, there is a drop rate of around 30-50%.
#
# Graph 2: Study Hours/ Week Histogram
#
# This graphs shows how many hours students report studying per week for these courses. The histogram shows a approximately normal distribution with most students studying around 3-5 hours per week. This graph represents course workload and may show that courses that have higher study hours may have higher drop rates if the work load is too demanding.
#
# Graph 3: Professor Recommendation(%) Histrogram
#
# This graph shows the precent of students who recommend the professor. The distribution is left-skewed with most courses' recommendation rates being between ~80 and 100%. Professor recomendation reflects student satisfation with the professor which mays that lower recommendation rates could correlate with higher drop rates.
#
# Graph 4: Average Grade GPA Histogram
#
# This graph shows the distribution of average course GPA vales. Most GPAs fall between 3.2 and 3.8, indicating that most courses have high average grades. Average GPA can indicate course difficulty, so courses with lower average GPAs may correlate with higher drop rates.
#
# Graph 5: Drop Rate Distrubtion by Quarter (Outliers Hidden: 1)
#
# This boxplot is comparing drop rates accross quarters FA22, SP23, and WI23 without outliers. The median drop rates between these three quarters appear relatively similar, which suggests that drop rates are not particularly affected by which quarter you take a course in.
#
# Graph 6: Drop Rate Distrubtion by Quarter (Full Range)
#
# This boxplot is comparing drop rates accross quarters FA22, SP23, and WI23 with outliers. This boxplot shows that there are few courses with very high dtops rates, however, it still follows the same pattern as the previous graph.

# %% [markdown]
# #### Section 2: Relationships Between Drop Rate and Course Factors
#
# Here we visualize how drop rate changes with workload, recommendation rate, and average grade, then compare low-drop vs high-drop courses using quartile-based groups.

# %% [markdown]
# ##### Bivariate Relationships

# %%
features = [
    ('study_hours', 'Study Hours / Week'),
    ('prof_recommend_pct', 'Professor Recommendation (%)'),
    ('grade_gpa', 'Average Grade GPA')
]
reg_colors = sns.color_palette('Dark2', 3)

fig, axes = plt.subplots(1, 3, figsize=(16, 4), sharey=True)
for ax, (xcol, xlabel), color in zip(axes, features, reg_colors):
    r, p = sp.stats.pearsonr(eda_df[xcol], eda_df['drop_rate'])
    sns.regplot(
        data=eda_df,
        x=xcol,
        y='drop_rate',
        color=color,
        scatter_kws={'alpha': 0.75, 's': 45},
        line_kws={'linestyle': '--', 'linewidth': 2},
        ci=None,
        ax=ax
    )
    ax.set_xlabel(xlabel)
    ax.set_title(f'Drop Rate vs {xlabel}')
    ax.text(0.05, 0.95, f'r = {r:.2f}\np = {p:.2f}', transform=ax.transAxes, 
            fontsize=12, verticalalignment='top',
            bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))

axes[0].set_ylabel('Drop Rate (%)')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/50/vgp82zgd5kx0ltcgp3lf3syc0000gn/T/ipykernel_76136/1633016777.py:10: DeprecationWarning: Please import `pearsonr` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   r, p = sp.stats.pearsonr(eda_df[xcol], eda_df['drop_rate'])

# %% [markdown]
# Scatter Plot 1: Drop Rate vs Study Hours/Weeks
#
# This scatter plot shows the relationship between study hours per week and course drop rate. The points are widely scattered and the trend line is almost flat, indicating little to no strong relationship between study hours and drop rate. This suggests that higher study hours per week may not correlate with whether students drop a course or not.
#
# Scatter Plot 2: Drop Rate vs Professor Recommendation (%)
#
# THis scatter plot shows the relationship between student recommendation ratings for professors and course drop rate. The trend line shows a slight negative relationship, indicating that courses with higher professor recommendation scores tend to have lower drop rates. This suggests that professor recommendation may weakly influence drop rates.
#
# Scatter Plot 3: Drop Rate vs Average Grade GPA
#
# This scatter plots shows the relation between average course GPA and drop rate. The trend line shows a slight negative relationship, indicating that courses with lower GPAs tend to have somewhat lower drop rates. This suggests that Average Grade GPA may weakly influence drop rates.

# %% [markdown]
# ##### Quartile-based comparison

# %%
q1 = eda_df['drop_rate'].quantile(0.25)
q3 = eda_df['drop_rate'].quantile(0.75)

low_drop = eda_df[eda_df['drop_rate'] <= q1].copy()
high_drop = eda_df[eda_df['drop_rate'] >= q3].copy()
low_drop['group'] = 'Low drop (Q1)'
high_drop['group'] = 'High drop (Q4)'
compare_df = pd.concat([low_drop, high_drop], ignore_index=True)

comparison_cols = ['study_hours', 'prof_recommend_pct', 'grade_gpa']
comparison_labels = ['Study Hours', 'Prof Recommendation (%)', 'Grade GPA']
boxplot_palettes = [
    {'Low drop (Q1)': '#66c2a5', 'High drop (Q4)': '#498b76ff'},
    {'Low drop (Q1)': '#8da0cb', 'High drop (Q4)': '#6e7c9e'},
    {'Low drop (Q1)': '#a6d854', 'High drop (Q4)': '#536c2b'}
]

fig, axes = plt.subplots(
    1, 3,
    figsize=(18, 5.4),
    constrained_layout=True
)
for ax, col, label, pal in zip(axes, comparison_cols, comparison_labels, boxplot_palettes):
    sns.boxplot(data=compare_df, x='group', y=col, hue='group', palette=pal, legend=False, ax=ax)
    sns.stripplot(data=compare_df, x='group', y=col, color='black', alpha=0.35, size=3, ax=ax)
    ax.set_title(label)
    ax.set_xlabel('')

    vals = compare_df[col].dropna()
    if col == 'prof_recommend_pct':
        low_q, high_q = vals.quantile([0.10, 0.995])
    else:
        low_q, high_q = vals.quantile([0.02, 0.98])
    span = high_q - low_q
    pad = span * 0.12 if span > 0 else 0.1
    ax.set_ylim(low_q - pad, high_q + pad)

fig.suptitle('Low vs High Drop-Rate Courses')
plt.show()

summary = pd.DataFrame({
    'low_drop_median': low_drop[comparison_cols].median(),
    'high_drop_median': high_drop[comparison_cols].median(),
})
summary['difference_high_minus_low'] = summary['high_drop_median'] - summary['low_drop_median']
display(summary.round(3))
# Out:
#                     low_drop_median  high_drop_median  \
# study_hours                    4.42              4.88
# prof_recommend_pct            95.90             91.40
# grade_gpa                      3.54              3.57
#
#                     difference_high_minus_low
# study_hours                              0.46
# prof_recommend_pct                      -4.50
# grade_gpa                                0.03

# %% [markdown]
# Boxplot 1: Study Hours
#
# This boxplot compares the study hours per week for courses with low and high drop rates. Courses with high drops rates have a higher median study hours than courses with low drop rates, and the spread of study hours is larger for larger for courses with high drop rates, which means that these courses hend to require more study time. This suggests that courses with higher study hours may correlate to higher drop rates.
#
# Boxplot 2: Professor Recommendation (%)
#
# This boxplot compares professor recommendation ratings between low and high drop courses. Courses with low drop rates have a higher median recommendation % than courses with high drop rates, and courses with high drop rates have greater variation. This indicates that students are more likely to stay in courses where the professor is rated more highly than ones that are not rated as high.
#
# Boxplot 3: Grade GPA
# This boxplot compares average course GPA between low and high drop courses. The medians GPAs for both groups are relatively similar, however courses with high drop rates have more variability. This suggests that average course GPA is not a good indicator to drop rates.

# %% [markdown]
# ### ETC AD NASEUM
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
#  > In most cases CAPES are completly optional and up to the student on whether or not they want to fill them out. However, there are some cases where students might get extra credit if
#  > they fill them out or in even rarer cases may be a part of the student's grade. Regardless, students know that by filling these forms out other students will be using them as a means to
#  > gather information about classes and professors.
#
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be
#    introduced during data collection and survey design and taken steps to
#    mitigate those?
#
#  > The CAPE is filled out by only those who complete the course. It could be
#  > biased to those who complete the course and might not be representative of the
#  > people who drop the course.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure
#    of personally identifiable information (PII) for example through
#    anonymization or not collecting information that isn't relevant for analysis?
#
#  > Names of instructors are personally identifiable information. However, it is
#  > important for the factors that might lead to drop rates.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
#  > The PII of the students filling out the form is not available so there is no way to know what groups we are collecting data from. As for professors, we can select different professors who
#  > have taught the same courses and different coureses taught by the same professors in order to not have any biased outcomes.
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an
#    individual can request their personal information be removed?
#
#  > We can have contact information or a form if any PII needs to be removed.
#
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of
#    bias and taken steps to mitigate or address these biases (e.g., stereotype
#    perpetuation, confirmation bias, imbalanced classes, or omitted confounding
#    variables)?
#
#  > The dataset from CAPE evaluation will only include feedback from those who
#  > completes the course. There might be a bias and might not be represenataive of
#  > those who dropped the class. Furthermore, students who might have found the course more frustrating or easy might be more keen to fill out evaluations, while the average student might not
#  > care that much. A way to mitigate these biases is to find courses where a large majority of students did evaluations.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary
#    statistics, and reports designed to honestly represent the underlying data?
#
#  > We will need to add disclaimers on any data that might not represent a
#  > certain group due to any bias from the datasets.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not
#    used or displayed unless necessary for the analysis?
#
#  > While PII such as names of instructors will be important in the analysis, it
#  > will be presented in a way that is discrimanatory. We will need to avoid
#  > pointing out a specific instructor for drop rates.
#
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  > Yes, as CAPES have extensive histories of courses and professors and are easily accessible should there be any issues we discover about our data.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings,
#    limitations, and biases of the model to relevant stakeholders in ways that
#    can be generally understood?
#
#  > Since the datasets can contain biases and missing data, there will need to be
#  > clear communication to show where the shortcomings happen.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
